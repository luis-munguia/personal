# %%
import pandas as pd
import numpy as np

# %%
livestock = pd.read_csv("cierre_2017.csv", encoding = 'latin1', low_memory = False)

# %%
livestock.head()
# Out:
#      Anio  Cveestado       Nomestado  Cveddr          Nomddr  Cvempio  \
# 0  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 1  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 2  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 3  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 4  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
#
#      Nommunicipio  Cveespecie Nomespecie  Cveproducto    Nomproducto  \
# 0  Aguascalientes         1.0      Abeja          7.0           Miel
# 1  Aguascalientes         3.0        Ave          1.0          Carne
# 2  Aguascalientes         3.0        Ave          8.0  Ganado en pie
# 3  Aguascalientes         3.0        Ave          4.0    Huevo-plato
# 4  Aguascalientes         4.0     Bovino          1.0          Carne
#
#       Volumen     Peso  Precio        Valor  Asacrificado
# 0     310.521    0.000   45.60    14160.036           0.0
# ...

# %%
livestock["Nomespecie"].unique()
# Out:
# array(['Abeja', 'Ave', 'Bovino', 'Caprino', 'Ovino', 'Porcino',
#        'Guajolote', nan], dtype=object)

# %%
bovine = livestock[livestock["Nomespecie"] == 'Bovino']

# %%
bovine.head()
# Out:
#       Anio  Cveestado       Nomestado  Cveddr          Nomddr  Cvempio  \
# 4   2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 5   2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 6   2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 16  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      2.0
# 17  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      2.0
#
#       Nommunicipio  Cveespecie Nomespecie  Cveproducto    Nomproducto  \
# 4   Aguascalientes         4.0     Bovino          1.0          Carne
# 5   Aguascalientes         4.0     Bovino          3.0  Ganado en pie
# 6   Aguascalientes         4.0     Bovino          6.0          Leche
# 16        Asientos         4.0     Bovino          1.0          Carne
# 17        Asientos         4.0     Bovino          3.0  Ganado en pie
#
#        Volumen     Peso  Precio       Valor  Asacrificado
# 4     9036.628  251.492   72.33  653577.630       35932.0
# ...

# %%
bovine_feet = bovine[bovine["Nomproducto"] == "Ganado en pie"]

# %%
bovine_feet.head()
# Out:
#       Anio  Cveestado       Nomestado  Cveddr          Nomddr  Cvempio  \
# 5   2017.0        1.0  Aguascalientes     1.0  Aguascalientes      1.0
# 17  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      2.0
# 27  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      3.0
# 39  2017.0        1.0  Aguascalientes     1.0  Aguascalientes      4.0
# 51  2017.0        1.0  Aguascalientes     1.0  Aguascalientes     10.0
#
#       Nommunicipio  Cveespecie Nomespecie  Cveproducto    Nomproducto  \
# 5   Aguascalientes         4.0     Bovino          3.0  Ganado en pie
# 17        Asientos         4.0     Bovino          3.0  Ganado en pie
# 27        Calvillo         4.0     Bovino          3.0  Ganado en pie
# 39           Cosío         4.0     Bovino          3.0  Ganado en pie
# 51        El Llano         4.0     Bovino          3.0  Ganado en pie
#
#       Volumen     Peso  Precio       Valor  Asacrificado
# 5   16643.691  463.200   39.04  649787.965           0.0
# ...

# %%
bovine_feet.sort_values(by=['Volumen'], ascending = False).head(15)
# Out:
#          Anio  Cveestado        Nomestado  Cveddr           Nomddr  Cvempio  \
# 25224  2017.0       24.0  San Luis Potosí   132.0            Ebano     40.0
# 176    2017.0        2.0  Baja California     3.0     Río Colorado      2.0
# 25796  2017.0       25.0          Sinaloa   136.0         Culiacán     13.0
# 3599   2017.0       10.0          Durango   191.0   Laguna-Durango     36.0
# 10967  2017.0       16.0        Michoacán    89.0        La Piedad    105.0
# 13199  2017.0       19.0       Nuevo León   102.0     Montemorelos     38.0
# 28318  2017.0       30.0         Veracruz   177.0          Choapas     61.0
# 28330  2017.0       30.0         Veracruz   177.0          Choapas    108.0
# 25784  2017.0       25.0          Sinaloa   136.0         Culiacán      6.0
# 3514   2017.0       10.0          Durango   191.0   Laguna-Durango      7.0
# 24550  2017.0       22.0        Querétaro   120.0        Cadereyta      7.0
# ...
